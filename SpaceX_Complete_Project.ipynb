# %% [markdown]
# # SpaceX Landing Outcomes - Complete Project

# %% [markdown]
# This notebook consolidates all steps from data collection to machine learning classification.

# %% [markdown]
# ## 1. Data Collection

# %%
import requests, pandas as pd
url = 'https://api.spacexdata.com/v4/launches/past'
launches = requests.get(url).json()
print('Total launches:', len(launches))

# %% [markdown]
# ## 2. Web Scraping
# Retrieve booster landing site data from Wikipedia.

# %%
import pandas as pd
site_url = 'https://en.wikipedia.org/wiki/Landing_Zones'
# Placeholder for example extraction

# %% [markdown]
# ## 3. Data Wrangling

# %%
# Example of merging data into a dataframe
# df = pd.DataFrame(launches)
# Further cleaning steps would be applied here

# %% [markdown]
# ## 4. Exploratory Data Analysis (SQL & Pandas)

# %%
# Example SQL query using pandas
# import sqlite3
# conn = sqlite3.connect(':memory:')
# df.to_sql('launches', conn)
# pd.read_sql('SELECT COUNT(*) FROM launches', conn)

# %% [markdown]
# ## 5. Visualizations

# %%
import matplotlib.pyplot as plt
# Placeholder for matplotlib plots

# %% [markdown]
# ## 6. Interactive Dashboards

# %%
# Dash and Folium examples would go here

# %% [markdown]
# ## 7. Machine Learning Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# features = df[['feature1', 'feature2']] # placeholder
# labels = df['landing_success'] # placeholder
# X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)
# model = DecisionTreeClassifier().fit(X_train, y_train)
# print('Train accuracy:', model.score(X_train, y_train))

# %% [markdown]
# ## Conclusion
# This consolidated notebook demonstrates the workflow for predicting SpaceX Falcon 9 first stage landings.
